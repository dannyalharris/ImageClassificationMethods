# %%
"""
Image pre-processing for machine learning
Author: Danial Haris Limi Hawari
"""

import PIL
import pathlib
path = r"C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder"
data_dir = pathlib.Path(path)


image_count = len(list(data_dir.glob('*/*.jpeg')))
print(image_count)

kamm = list(data_dir.glob("Kamm/*.jpeg"))
PIL.Image.open(str(kamm[0]))

bürste = list(data_dir.glob("Bürste/*.jpeg"))
PIL.Image.open(str(bürste[0]))


for i in range(len(kamm)):
        print([i])
        print(kamm[i])
        image = Image.open(kamm[i])
        new_image = image.resize((256, 256))
        new_image.save(r"C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder_neu\Kamm\image_"+str(i)+".png")
# Out:
# 800
# [0]
# C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder\Kamm\file (1).jpeg
# [1]
# C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder\Kamm\file (10).jpeg
# [2]
# C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder\Kamm\file (100).jpeg
# [3]
# C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder\Kamm\file (101).jpeg
# [4]
# C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder\Kamm\file (102).jpeg
# [5]
# C:\Users\danny\OneDrive - bwedu\EU4M MASTER SUBJECTS\SEMESTER 2\Künstliche Intelligenz\BuildData\lida_onka_trainingsbilder\Kamm\file (103).jpeg
# [6]
# ...
